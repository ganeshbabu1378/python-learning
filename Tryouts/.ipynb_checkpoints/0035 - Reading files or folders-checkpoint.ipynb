# %%
pwd
# Out:
# 'C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning\\Tryouts'

# %%
f = open('practice.txt','w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning\\Tryouts'

# %%
os.listdir('C:\\Users')
# Out:
# ['All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'ganes',
#  'Ganesh Babu',
#  'GB',
#  'Guest_User',
#  'Public']

# %%
import shutil

# %%
shutil.move('practice.txt' , 'C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning')
# Out:
# 'C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning\\practice.txt'

# %%
os.listdir('C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning')
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'myExample.py',
#  'myFirstNoteBook.ipynb',
#  'practice.txt',
#  'README.md',
#  'Tryouts']

# %%
import send2trash

# %%
shutil.move('C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning\\practice.txt' , os.getcwd())
# Out:
# 'C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning\\Tryouts\\practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '0001 - Python Numbers.ipynb',
#  '0002 - Variables assignment.ipynb',
#  '0003 - Strings.ipynb',
#  '0004 - String Immutability.ipynb',
#  '0005 - String formats.ipynb',
#  '0006 - List.ipynb',
#  '0007 - Dictionaries.ipynb',
#  '0008 - Tuples.ipynb',
#  '0009 - Sets.ipynb',
#  '0010 - Boolean.ipynb',
#  '0011 - Simple Text File.ipynb',
#  '0012 - Comparison operators.ipynb',
#  '0013 - Control Statements - IF.ipynb',
#  '0014 - Control Statements - For Loop.ipynb',
#  '0015 - Control Statements - While loop.ipynb',
#  '0016 - Useful operators.ipynb',
#  '0017 - List comprehensions.ipynb',
#  '0018 - Methods & Functions.ipynb',
#  '0019 - Basic Functions.ipynb',
#  '0020 - Interacting with other functions.ipynb',
#  '0021 - args & kwargs.ipynb',
#  '0022 - Practice Functions.ipynb',
#  '0023 - Lambda Exp.ipynb',
#  '0024 - Nested variables.ipynb',
#  '0025 - Interactive game .ipynb',
#  '0026 - OOP.ipynb',
#  '0027 - Inheritance & Polymorphism.ipynb',
# ...

# %%
send2trash.send2trash('C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning\\Tryouts\\practice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '0001 - Python Numbers.ipynb',
#  '0002 - Variables assignment.ipynb',
#  '0003 - Strings.ipynb',
#  '0004 - String Immutability.ipynb',
#  '0005 - String formats.ipynb',
#  '0006 - List.ipynb',
#  '0007 - Dictionaries.ipynb',
#  '0008 - Tuples.ipynb',
#  '0009 - Sets.ipynb',
#  '0010 - Boolean.ipynb',
#  '0011 - Simple Text File.ipynb',
#  '0012 - Comparison operators.ipynb',
#  '0013 - Control Statements - IF.ipynb',
#  '0014 - Control Statements - For Loop.ipynb',
#  '0015 - Control Statements - While loop.ipynb',
#  '0016 - Useful operators.ipynb',
#  '0017 - List comprehensions.ipynb',
#  '0018 - Methods & Functions.ipynb',
#  '0019 - Basic Functions.ipynb',
#  '0020 - Interacting with other functions.ipynb',
#  '0021 - args & kwargs.ipynb',
#  '0022 - Practice Functions.ipynb',
#  '0023 - Lambda Exp.ipynb',
#  '0024 - Nested variables.ipynb',
#  '0025 - Interactive game .ipynb',
#  '0026 - OOP.ipynb',
#  '0027 - Inheritance & Polymorphism.ipynb',
# ...

# %%
file_path = 'C:\\Users\\Ganesh Babu\\GitHub-workspace\\python-learning'
for folder , sub_folders,files in os.walk(file_path):
    print(f'Currently looking at {folder}')
    print('\n')
    print('The Subfolders are :')
    for sub_fold in sub_folders:
        print(f'\tSubfolder : {sub_fold}')
    print('\n')
    print('the files are: ')
    for f in files: 
        print(f'\t\tFile : {f}')
    print('\n')
# Out:
# Currently looking at C:\Users\Ganesh Babu\GitHub-workspace\python-learning
#
#
# The Subfolders are :
# 	Subfolder : .git
# 	Subfolder : .ipynb_checkpoints
# 	Subfolder : Tryouts
#
#
# the files are:
# 		File : myExample.py
# 		File : myFirstNoteBook.ipynb
# 		File : README.md
#
#
# Currently looking at C:\Users\Ganesh Babu\GitHub-workspace\python-learning\.git
#
#
# The Subfolders are :
# 	Subfolder : hooks
# 	Subfolder : info
# 	Subfolder : logs
# 	Subfolder : objects
# 	Subfolder : refs
#
#
# the files are:
# 		File : COMMIT_EDITMSG
# 		File : config
# 		File : description
# 		File : HEAD
# 		File : index
# 		File : packed-refs
#
#
# Currently looking at C:\Users\Ganesh Babu\GitHub-workspace\python-learning\.git\hooks
#
#
# The Subfolders are :
#
#
# the files are:
# 		File : applypatch-msg.sample
# 		File : commit-msg.sample
# 		File : fsmonitor-watchman.sample
# 		File : post-update.sample
# 		File : pre-applypatch.sample
# 		File : pre-commit.sample
# ...
