# %%
hungry = True

if hungry:
    print('FEED ME!')
else:
    print('Im not hungry')
# Out:
# FEED ME!

# %%
loc = 'Bank'

if loc == 'Auto Shop' :
    print("Cars are cool!");
elif loc == 'Bank':
    print("Money is cool!");
else:
    print('I do not  know much');
# Out:
# Money is cool!
