# %%
d = {'k1':1 , 'k2':2}

# %%
x = { str(x):x**2 for x in range(10)}

# %%
x
# Out:
# {'0': 0,
#  '1': 1,
#  '2': 4,
#  '3': 9,
#  '4': 16,
#  '5': 25,
#  '6': 36,
#  '7': 49,
#  '8': 64,
#  '9': 81}

# %%
for k in d.values():
    print (k)
# Out:
# ('k1', 1)
# ('k2', 2)

# %%
a = (1 , 2)
